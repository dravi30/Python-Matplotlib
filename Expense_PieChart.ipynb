# %% [markdown]
# ![Image](Home.png)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_vals = [1600,600,100,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car","Other Utilities"]

# %%
plt.axis("equal")
plt.pie(exp_vals,labels = exp_labels,radius=1.5,shadow=True, autopct='%0.1f%%',explode=[0,0,0,0,0.2])
plt.show()
